# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\bulle\Documents\Python-Instancart Basket Analysis'
orders_products_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_4-7.pkl'))

# %%
orders_products_merged = orders_products_merged.dropna(subset=['order_dow'])

# %%
orders_products_merged['order_dow'].value_counts(dropna = False)
# Out:
# 0.0    6204182
# 1.0    5660230
# 6.0    4496490
# 2.0    4213830
# 5.0    4205791
# 3.0    3840534
# 4.0    3783802
# Name: order_dow, dtype: int64

# %%
orders_products_merged.rename(columns = {'orders_day_of_the_week' : 'order_day_of_the_week'}, inplace = True)

# %%
orders_products_merged.head(5)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_the_week  \
# 0  3139998.0    138.0    prior          28.0                    6.0
# 1  1977647.0    138.0    prior          30.0                    6.0
# 2   389851.0    709.0    prior           2.0                    0.0
# 3   652770.0    764.0    prior           1.0                    3.0
# 4  1813452.0    764.0    prior           3.0                    4.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0               11.0                     3.0           1                5.0
# 1               17.0                    20.0           1                1.0
# 2               21.0                     6.0           1               20.0
# 3               13.0                     NaN           1               10.0
# 4               17.0                     9.0           1               11.0
#
#    reordered _merge  Unnamed: 0                product_name  aisle_id  \
# ...

# %%
orders_products_merged.drop(columns = 'Unnamed: 0')
# Out:
#            order_id   user_id eval_set  order_number  order_day_of_the_week  \
# 0         3139998.0     138.0    prior          28.0                    6.0
# 1         1977647.0     138.0    prior          30.0                    6.0
# 2          389851.0     709.0    prior           2.0                    0.0
# 3          652770.0     764.0    prior           1.0                    3.0
# 4         1813452.0     764.0    prior           3.0                    4.0
# ...             ...       ...      ...           ...                    ...
# 32404865  1788356.0  200215.0    prior           2.0                    0.0
# 32404866  3401313.0  200377.0    prior           1.0                    4.0
# 32404867   809510.0  200873.0    prior           5.0                    3.0
# 32404868  2359893.0  200873.0    prior           9.0                    3.0
# 32404869  2385091.0  205926.0    prior          11.0                    1.0
#
# ...

# %%
orders_products_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_4-7.pkl'))
