# %% [markdown]
# # Import Libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Data

# %%
path = r'C:\Users\bulle\Documents\Python-Instancart Basket Analysis'
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products.checked.csv'), index_col = False)
orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
orders_products_combined
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32434484   2977660   206209    prior            13          1
# 32434485   2977660   206209    prior            13          1
# 32434486   2977660   206209    prior            13          1
# 32434487   2977660   206209    prior            13          1
# 32434488   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
orders_products_combined.isnull().sum()
# Out:
# order_id                        0
# user_id                         0
# eval_set                        0
# order_number                    0
# order_dow                       0
# order_hour_of_day               0
# days_since_prior_order    2078068
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# _merge                          0
# dtype: int64

# %%
orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
df_prods.isnull().sum()
# Out:
# Unnamed: 0       0
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# prices           0
# dtype: int64

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
#testing a merge for "order_products_combined" with "df_prods"
ords_prods_merged = orders_products_combined.merge(df_prods, on = 'product_id', how = 'right')

# %%
ords_prods_merged.head()
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0  3139998.0    138.0    prior          28.0        6.0               11.0
# 1  1977647.0    138.0    prior          30.0        6.0               17.0
# 2   389851.0    709.0    prior           2.0        0.0               21.0
# 3   652770.0    764.0    prior           1.0        3.0               13.0
# 4  1813452.0    764.0    prior           3.0        4.0               17.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     3.0           1                5.0        0.0   both
# 1                    20.0           1                1.0        1.0   both
# 2                     6.0           1               20.0        0.0   both
# 3                     NaN           1               10.0        0.0   both
# 4                     9.0           1               11.0        1.0   both
#
# ...

# %%
ords_prods_merged.drop(columns = ['Unnamed: 0'])
# Out:
#            order_id   user_id eval_set  order_number  order_dow  \
# 0         3139998.0     138.0    prior          28.0        6.0
# 1         1977647.0     138.0    prior          30.0        6.0
# 2          389851.0     709.0    prior           2.0        0.0
# 3          652770.0     764.0    prior           1.0        3.0
# 4         1813452.0     764.0    prior           3.0        4.0
# ...             ...       ...      ...           ...        ...
# 32404865  1788356.0  200215.0    prior           2.0        0.0
# 32404866  3401313.0  200377.0    prior           1.0        4.0
# 32404867   809510.0  200873.0    prior           5.0        3.0
# 32404868  2359893.0  200873.0    prior           9.0        3.0
# 32404869  2385091.0  205926.0    prior          11.0        1.0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                      11.0                     3.0           1
# 1                      17.0                    20.0           1
# ...

# %%
ords_prods_merged.isnull().sum()
# Out:
# order_id                       11
# user_id                        11
# eval_set                       11
# order_number                   11
# order_dow                      11
# order_hour_of_day              11
# days_since_prior_order    2076107
# product_id                      0
# add_to_cart_order              11
# reordered                      11
# _merge                         11
# Unnamed: 0                      0
# product_name                    0
# aisle_id                        0
# department_id                   0
# prices                          0
# dtype: int64

# %%
ords_prods_merged.shape
# Out:
# (32404870, 16)

# %%
orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
# check "_merge"
ords_prods_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
orders_products_combined['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
#Export ords_prods_merged as "orders_products_merged.pkl"
ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_produts_merged.pkl'))
